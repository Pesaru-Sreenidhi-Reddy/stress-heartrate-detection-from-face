# %%
from bing_image_downloader import downloader
downloader.download("stressed person portrait",output_dir='StressDataOriginal',filter='photo')
# Out:
# [%] Downloading Images to /Users/sreenidhireddy/Downloads/Stress Detection not executing on my desktop/StressDetection/StressDataOriginal/stressed person portrait
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i0.hippopx.com/photos/741/650/458/headache-image-man-stress-preview.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://i.huffpost.com/gen/1032480/images/o-STRESSED-MAN-facebook.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://p1.pxfuel.com/preview/847/347/621/headache-image-man-stress.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://dadsdivorce.com/wp-content/uploads/2016/10/stressed-man.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://images.huffingtonpost.com/2015-11-17-1447780849-1501051-Stressed_4.jpeg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("relaxed or happy person portrait",output_dir='StressDataOriginal',filter='photo')
# Out:
# [%] Downloading Images to /Users/sreenidhireddy/Downloads/Stress Detection not executing on my desktop/StressDetection/StressDataOriginal/relaxed person portrait
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://huntforhopewellness.com/wp-content/uploads/2014/12/relaxed-calm-person.jpg
# [!] Issue getting: https://huntforhopewellness.com/wp-content/uploads/2014/12/relaxed-calm-person.jpg
# [!] Error:: HTTP Error 502: Bad Gateway
# [%] Downloading Image #1 from http://fullhdwall.com/wp-content/uploads/2018/02/Man-Relax.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/89/31/51/8931510cb3d6539613f50c10e1fda0b1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/91/66/85/9166851b68df64d81acf2bf6aefdf938.jpg
# [%] File Downloaded !
#
# ...
